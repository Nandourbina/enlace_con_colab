# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandourbina/enlace_con_colab/blob/main/Introduccion_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola mundo desde Bootcamp 217")
# Out:
# Hola mundo desde Bootcamp 217

# %% [markdown]
# $\sqrt(3x-1)+(1+x)^2$

# %%
import time
print("Durmiendo")
time.sleep(30) #¡dormir por un tiempo; interrumpeme!
print("Termine de dormir")
# Out:
# Durmiendo
# Termine de dormir

# %%
# !ls /bin
# Out:
# '['				      mkdir
#  7z				      mkfifo
#  7za				      mknod
#  7zr				      mktemp
#  aclocal			      mm2gv
#  aclocal-1.16			      more
#  acyclic			      mount
#  add-apt-repository		      mountpoint
#  addpart			      mpexpand
#  addr2line			      mpic++
#  aggregate_profile		      mpicc
#  apropos			      mpiCC
#  apt				      mpicc.openmpi
#  apt-add-repository		      mpiCC.openmpi
#  apt-cache			      mpic++.openmpi
#  apt-cdrom			      mpicxx
#  apt-config			      mpicxx.openmpi
#  apt-extracttemplates		      mpiexec
#  apt-ftparchive			      mpiexec.openmpi
#  apt-get			      mpif77
#  apt-key			      mpif77.openmpi
#  apt-mark			      mpif90
#  apt-sortpkgs			      mpif90.openmpi
#  ar				      mpifort
#  arch				      mpifort.openmpi
#  as				      mpijavac
#  asan_symbolize			      mpijavac.pl
#  asan_symbolize-14		      mpirun
#  autoconf			      mpirun.openmpi
#  autoheader			      mv
#  autom4te			      mysql_config
#  automake			      namei
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %%html
# <marquee style='width: 30%; color: green'><b>Hola Mundo dede Bootcamp</b></marquee>
# Out:
# <marquee style='width: 30%; color: green'><b>Hola Mundo dede Bootcamp</b></marquee>

# %%
import numpy as np
from matplotlib import pyplot as plt

#Generar datos aleatorios
ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

#Trazar el gráfico de línea con color azul ('b')
plt.plot(x, ys, '-', color='blue')

#Rellenar el área debajo de la línea con color Amarillo  ('yellow')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='yellow', alpha=0.6)

#Agregar un título al gráfico
plt.title=("Ejemplo de Rellenos y Alfa")

#Mostrar el gráfico
plt.show()
